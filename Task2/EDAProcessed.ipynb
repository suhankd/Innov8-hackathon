# %%
import pandas as pd

data = pd.read_csv('processedData.csv')

data_info = data.info()
data_head = data.head()

data_info, data_head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  86 non-null     int64
#  1   Age                         86 non-null     int64
#  2   Gender                      84 non-null     float64
#  3   Clan                        86 non-null     object
#  4   family_mental_history       86 non-null     int64
#  5   Support Received            86 non-null     int64
#  6   Mission Interference        86 non-null     int64
#  7   Clan Size                   86 non-null     float64
#  8   knowledge_about_facilities  86 non-null     int64
#  9   seeken_help                 86 non-null     int64
#  10  frequency_of_leaves         86 non-null     int64
#  11  job_physical_consequence    86 non-null     int64
#  12  job_mental_consequence      86 non-null     int64
#  13  comrade_relationships       86 non-null     int64
#  14  superior_relationship       86 non-null     int64
#  15  physical_assessment         86 non-null     int64
#  16  mental_assessment           86 non-null     int64
#  17  Internal Dialogue           86 non-null     object
#  18  Betrayal                    86 non-null     int64
# dtypes: float64(2), int64(15), object(2)
# memory usage: 12.9+ KB
# (None,
#     Unnamed: 0  Age  Gender        Clan  family_mental_history  \
#  0          24   33     1.0  Zyphorians                      1
#  1          25   35     1.0  Zyphorians                      1
#  2          33   42     1.0  Zyphorians                      1
#  3          45   38     0.0  Zyphorians                      1
#  4          49   30     1.0  Zyphorians                      1
#
#     Support Received  Mission Interference  Clan Size  \
#  0                 1                     2       63.0
#  1                 1                     3     1200.0
#  2                 1                     3       63.0
#  3                 1                     3       63.0
#  4                 1                     2       63.0
#
#     knowledge_about_facilities  seeken_help  frequency_of_leaves  \
#  0                           1            2                    0
#  1                           2            0                    4
#  2                           2            2                    4
#  3                           2            2                    2
#  4                           0            0                    0
#
#     job_physical_consequence  job_mental_consequence  comrade_relationships  \
#  0                         1                       1                      2
#  1                         2                       1                      1
#  2                         0                       1                      1
#  3                         1                       1                      1
#  4                         0                       1                      1
#
#     superior_relationship  physical_assessment  mental_assessment  \
#  0                      2                    1                  2
#  1                      2                    1                  2
#  2                      1                    0                  2
#  3                      2                    1                  1
#  4                      2                    1                  1
#
#                                     Internal Dialogue  Betrayal
#  0                Relatively new job. Ask again later         0
#  1  Sometimes I think  about using drugs for my me...         1
#  2  I selected my current employer based on its po...         1
#  3  Our health plan has covered my psychotherapy a...         1
#  4  I just started a new job last week hence a lot...         0  )

# %%
sns.set(style="whitegrid")

# Correlation matrix
correlation_matrix = numeric_data.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Key Metrics')
plt.show()

# %%
num_cols = data.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(16, 12))

for i, col in enumerate(num_cols, 1):
    plt.subplot(5, 4, i)
    sns.histplot(data[col], kde=True, color="skyblue")
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(16, 12))

for i, col in enumerate(num_cols, 1):
    plt.subplot(5, 4, i)
    sns.boxplot(y=data[col], color="skyblue")
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()

plt.show()
